# %%
Instructor_question_weighting= {'old_EN':{1: 0, 2: 1.5, 3: 2.0, 4: 0.15, 5: 1.5, 6: 1.5, 7: 0, 8: 0, 9: 0, 10: 3.5},'EN':{1: 0, 2: 1.5, 3: 2.0, 4: 0.15, 5: 1.5, 6: 1.5, 7: 0, 8: 0, 9: 0, 10: 3.5}, 'ED': {}}# Currently only 2,3,5,6,10 are in our data
Instructor_question_weighting[1] # better not index from 0 lol :p

# Get a 3 column list of question numbers, questions, and weightings
import os
import pandas as pd

# Get a list of the data files
data_files = os.listdir('data/')
for i in data_files:
    if i[-4:]!='.csv':
        data_files.remove(i)
print(data_files)
df = pd.DataFrame()
list_ = []

# Iterate through the list of data files, creating a df for each
for file_ in data_files:
    df = pd.read_csv('data/'+file_,index_col=None, header=0)
    print(len(df))
    list_.append(df)

# concatenated array
df = pd.concat(list_, axis = 0, ignore_index = True)

# Drop all columns not of interest
df.drop(df.columns.difference(['College Code','Question Number','Question']), 1, inplace=True)
df.drop_duplicates(inplace = True)
df.insert(0, 'Question Weighting', 0)

# Map the question weighting to each before saving

df.to_csv('mappings.csv', index=False)
df.head(60)
# Out:
# ['GCOE.csv', 'JRCOE.csv']
# 22540
# 18615
#        Question Weighting College Code  Question Number  \
# 0                       0           EN                4
# 1                       0           EN                6
# 2                       0           EN                7
# 3                       0           EN               16
# 4                       0           EN               33
# 690                     0           EN                3
# 694                     0           EN               27
# 4610                    0           EN                2
# 4611                    0           EN                3
# 4612                    0           EN                5
# 4613                    0           EN                6
# 4614                    0           EN               10
# 22540                   0           ED                2
# 22541                   0           ED                3
# 22542                   0           ED                4
# 22543                   0           ED                6
# 22544                   0           ED                8
#
#                                                 Question
# 0      Instructor was well organized and made adequat...
# 1      Instructor related course material to real lif...
# 2      In general, the instructor taught this course ...
# 3      The lab exercises increased your interest in t...
# 4      This course increased your ability to use the ...
# 690    Instructor gave a clear presentation of the ma...
# 694    This course increased your ability to use curr...
# 4610   The instructor was well-organized and made ade...
# 4611   Class time was well used and contributed to my...
# 4612   The instructor related course material to prof...
# 4613   The way in which the course was taught helped ...
# 4614   In general, the instructor taught this course ...
# 22540  Extend to which the instructor contributed to ...
# 22541  Instructor displayed a thorough knowledge of t...
# 22542  Quality of readings and/or assigned course mat...
# 22543  Instructor's ability to encourage critical and...
# 22544  Overall, the instructor's teaching effectivene...

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
years = [str(i) for i in years]
sems = ['10', '20', '30']
sem_names  = ['Fall', 'Spring', 'Summer']
Term_code_dict = {}
for i in range(len(years)):
    for j in range(len(sems)):
        Term_code_dict[str(years[i]+sems[j])] = sem_names[j]+' '+years[i]
Term_code_dict
# Out:
# {'201010': 'Fall 2010',
#  '201020': 'Spring 2010',
#  '201030': 'Summer 2010',
#  '201110': 'Fall 2011',
#  '201120': 'Spring 2011',
#  '201130': 'Summer 2011',
#  '201210': 'Fall 2012',
#  '201220': 'Spring 2012',
#  '201230': 'Summer 2012',
#  '201310': 'Fall 2013',
#  '201320': 'Spring 2013',
#  '201330': 'Summer 2013',
#  '201410': 'Fall 2014',
#  '201420': 'Spring 2014',
#  '201430': 'Summer 2014',
#  '201510': 'Fall 2015',
#  '201520': 'Spring 2015',
#  '201530': 'Summer 2015',
#  '201610': 'Fall 2016',
#  '201620': 'Spring 2016',
#  '201630': 'Summer 2016',
#  '201710': 'Fall 2017',
#  '201720': 'Spring 2017',
#  '201730': 'Summer 2017',
#  '201810': 'Fall 2018',
#  '201820': 'Spring 2018',
#  '201830': 'Summer 2018',
#  '201910': 'Fall 2019',
#  '201920': 'Spring 2019',
#  '201930': 'Summer 2019',
#  '202010': 'Fall 2020',
#  '202020': 'Spring 2020',
#  '202030': 'Summer 2020',
#  '202110': 'Fall 2021',
#  '202120': 'Spring 2021',
#  '202130': 'Summer 2021',
#  '202210': 'Fall 2022',
#  '202220': 'Spring 2022',
#  '202230': 'Summer 2022',
#  '202310': 'Fall 2023',
#  '202320': 'Spring 2023',
#  '202330': 'Summer 2023'}

# %% [markdown]
# <h2> Mapping of Subject Codes to Colors for Frontend Chips </h2>

# %%
from api_functions import *
db = mongo_driver()
unique_subjects = []
for j in AGG_COLLECTION_NAMES:
    temp_df, _ = query_df_from_mongo(db, {},collections = [j])
    [unique_subjects.append(i) for i in list(temp_df['Subject Code'].unique())]
    
print(unique_subjects)
print(len(unique_subjects))
# Out:
# ['ENGR', 'AME', 'CH E', 'CEES', 'ECE', 'TCOM', 'I E', 'C S', 'BIOE', 'ISE', 'BME', 'DSA', 'EDAH', 'EACS', 'EDS', 'EDSP', 'ILAC', 'EIPT', 'EDPY', 'EDEC', 'EDUC', 'EDMA', 'EDLT', 'EDEN', 'EDSC', 'EDSS', 'EDEL', 'EDRG', 'EDPC', 'EDWL', 'CAS', 'ANTH', 'AFAM', 'CHEY', 'CHOC', 'CHER', 'BOT', 'CHEM', 'MBIO', 'KIOW', 'LTRS', 'CL C', 'LAT', 'GRK', 'ECON', 'COMM', 'ENGL', 'FVS', 'HES', 'HIST', 'H R', 'HSCI', 'IPE', 'MATH', 'LIS', 'ARAB', 'FR', 'CHIN', 'GERM', 'ITAL', 'MLLL', 'SPAN', 'JAPN', 'LING', 'PORT', 'RUSS', 'NAS', 'HEBR', 'PHIL', 'ASTR', 'PHYS', 'P SC', 'ODYN', 'PSY', 'RELS', 'S WK', 'SOC', 'ZOO', 'W S', 'BIOL', 'KM', 'GEOL', 'FMS', 'WGS', 'PBIO', 'PERS', 'CREK', 'UNIV', 'ENST', 'NPNG', 'LGBT', 'MRS', 'PHCH', 'HMS', '|D', 'RCPL', 'ARCH', 'CNS', 'END', 'LA', 'PDC', 'ACCT', 'MKT', 'SCM', 'EMBA', 'MGT', 'BAD', 'MIS', 'MIT', 'ENT', 'ENGB', 'BC', 'FIN', 'EMGT', 'LS', 'FRAN', 'DRAM', 'MUNM', 'VOIC', 'MUTH', 'MUSC', 'ARTH', 'VIOL', 'AHI', 'MUTE', 'MTHR', 'DES', 'ART', 'DANC', 'TRMP', 'BASS', 'MUED', 'EUPH', 'TROM', 'PIAN', 'VIOA', 'CLAR', 'FRH', 'SAX', 'ARNM', 'PCUS', 'GDMA', 'HARP', 'COMP', 'OBOE', 'UGRE', 'MUTK', 'CELO', 'AHi', 'SRRE', 'FLUT', 'ORGN', 'TUBA', 'ATC', 'MULI', 'LDMA', 'ARTC', 'MUS', 'BASN', 'GTAR', 'JRRE', 'GRRE', 'AHI.', 'GEOG', 'METR', 'GIS', 'AGSC', 'IAS', 'JMC', 'PE', 'GEOL', 'GPHY', 'GE', 'GEOL1034-012/METR']
# 174

# %%
# Now I want to build a dict comprehension to map the individual subjects to colors
# Got this from online: https://www.quora.com/How-do-I-generate-n-visually-distinct-RGB-colours-in-Python
def get_spaced_colors(n):
    max_value = 16581375 #255**3
    interval = int(max_value / n)
    colors = [hex(I)[2:].zfill(6) for I in range(0, max_value, interval)]
    return ['#'+str(i) for i in colors]
    
    return [(int(i[:2], 16), int(i[2:4], 16), int(i[4:], 16)) for i in colors]
colors = get_spaced_colors(len(unique_subjects)+1)
colors = colors[1:]
# color_list = get_spaced_colors
color_map = {unique_subjects[i]:colors[i] for i in range(len(unique_subjects))}

# %%
for i in
# Out:
# {'ENGR': '#01721e', 'AME': '#02e43c', 'CH E': '#04565a', 'CEES': '#05c878', 'ECE': '#073a96', 'TCOM': '#08acb4', 'I E': '#0a1ed2', 'C S': '#0b90f0', 'BIOE': '#0d030e', 'ISE': '#0e752c', 'BME': '#0fe74a', 'DSA': '#115968', 'EDAH': '#12cb86', 'EACS': '#143da4', 'EDS': '#15afc2', 'EDSP': '#1721e0', 'ILAC': '#1893fe', 'EIPT': '#1a061c', 'EDPY': '#1b783a', 'EDEC': '#1cea58', 'EDUC': '#1e5c76', 'EDMA': '#1fce94', 'EDLT': '#2140b2', 'EDEN': '#22b2d0', 'EDSC': '#2424ee', 'EDSS': '#25970c', 'EDEL': '#27092a', 'EDRG': '#287b48', 'EDPC': '#29ed66', 'EDWL': '#2b5f84', 'CAS': '#2cd1a2', 'ANTH': '#2e43c0', 'AFAM': '#2fb5de', 'CHEY': '#3127fc', 'CHOC': '#329a1a', 'CHER': '#340c38', 'BOT': '#357e56', 'CHEM': '#36f074', 'MBIO': '#386292', 'KIOW': '#39d4b0', 'LTRS': '#3b46ce', 'CL C': '#3cb8ec', 'LAT': '#3e2b0a', 'GRK': '#3f9d28', 'ECON': '#410f46', 'COMM': '#428164', 'ENGL': '#43f382', 'FVS': '#4565a0', 'HES': '#46d7be', 'HIST': '#4849dc', 'H R': '#49bbfa', 'HSCI': '#4b2e18', 'IPE': '#4ca036', 'MATH': '#4e1254', 'LIS': '#4f8472', 'ARAB': '#50f690', 'FR': '#5268ae', 'CHIN': '#53dacc', 'GERM': '#554cea', 'ITAL': '#56bf08', 'MLLL': '#583126', 'SPAN': '#59a344', 'JAPN': '#5b1562', 'LING': '#5c8780', 'PORT': '#5df99e', 'RUSS': '#5f6bbc', 'NAS': '#60ddda', 'HEBR': '#624ff8', 'PHIL': '#63c216', 'ASTR': '#653434', 'PHYS': '#66a652', 'P SC': '#681870', 'ODYN': '#698a8e', 'PSY': '#6afcac', 'RELS': '#6c6eca', 'S WK': '#6de0e8', 'SOC': '#6f5306', 'ZOO': '#70c524', 'W S': '#723742', 'BIOL': '#73a960', 'KM': '#751b7e', 'GEOL': '#f73a0a', 'FMS': '#77ffba', 'WGS': '#7971d8', 'PBIO': '#7ae3f6', 'PERS': '#7c5614', 'CREK': '#7dc832', 'UNIV': '#7f3a50', 'ENST': '#80ac6e', 'NPNG': '#821e8c', 'LGBT': '#8390aa', 'MRS': '#8502c8', 'PHCH': '#8674e6', 'HMS': '#87e704', '|D': '#895922', 'RCPL': '#8acb40', 'ARCH': '#8c3d5e', 'CNS': '#8daf7c', 'END': '#8f219a', 'LA': '#9093b8', 'PDC': '#9205d6', 'ACCT': '#9377f4', 'MKT': '#94ea12', 'SCM': '#965c30', 'EMBA': '#97ce4e', 'MGT': '#99406c', 'BAD': '#9ab28a', 'MIS': '#9c24a8', 'MIT': '#9d96c6', 'ENT': '#9f08e4', 'ENGB': '#a07b02', 'BC': '#a1ed20', 'FIN': '#a35f3e', 'EMGT': '#a4d15c', 'LS': '#a6437a', 'FRAN': '#a7b598', 'DRAM': '#a927b6', 'MUNM': '#aa99d4', 'VOIC': '#ac0bf2', 'MUTH': '#ad7e10', 'MUSC': '#aef02e', 'ARTH': '#b0624c', 'VIOL': '#b1d46a', 'AHI': '#b34688', 'MUTE': '#b4b8a6', 'MTHR': '#b62ac4', 'DES': '#b79ce2', 'ART': '#b90f00', 'DANC': '#ba811e', 'TRMP': '#bbf33c', 'BASS': '#bd655a', 'MUED': '#bed778', 'EUPH': '#c04996', 'TROM': '#c1bbb4', 'PIAN': '#c32dd2', 'VIOA': '#c49ff0', 'CLAR': '#c6120e', 'FRH': '#c7842c', 'SAX': '#c8f64a', 'ARNM': '#ca6868', 'PCUS': '#cbda86', 'GDMA': '#cd4ca4', 'HARP': '#cebec2', 'COMP': '#d030e0', 'OBOE': '#d1a2fe', 'UGRE': '#d3151c', 'MUTK': '#d4873a', 'CELO': '#d5f958', 'AHi': '#d76b76', 'SRRE': '#d8dd94', 'FLUT': '#da4fb2', 'ORGN': '#dbc1d0', 'TUBA': '#dd33ee', 'ATC': '#dea60c', 'MULI': '#e0182a', 'LDMA': '#e18a48', 'ARTC': '#e2fc66', 'MUS': '#e46e84', 'BASN': '#e5e0a2', 'GTAR': '#e752c0', 'JRRE': '#e8c4de', 'GRRE': '#ea36fc', 'AHI.': '#eba91a', 'GEOG': '#ed1b38', 'METR': '#ee8d56', 'GIS': '#efff74', 'AGSC': '#f17192', 'IAS': '#f2e3b0', 'JMC': '#f455ce', 'PE': '#f5c7ec', 'GPHY': '#f8ac28', 'GE': '#fa1e46', 'GEOL1034-012/METR': '#fb9064'}
